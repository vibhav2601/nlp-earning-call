# %%
# !git clone https://github.com/vibhav2601/nlp-earning-call
# %cd nlp-earning-call
# Out:
# Cloning into 'nlp-earning-call'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (250/250), done.
# remote: Total 264 (delta 11), reused 261 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (264/264), 18.39 MiB | 19.95 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/nlp-earning-call

# %%
# !pip install -r requirements.txt
# If you added hf_xet or other extras, do:
# !pip install huggingface_hub[hf_xet] jsonlines scikit-learn
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.6.1)
# Collecting aiohttp==3.11.16 (from -r requirements.txt (line 2))
#   Downloading aiohttp-3.11.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: aiosignal==1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (1.3.2)
# Collecting async-timeout==5.0.1 (from -r requirements.txt (line 4))
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs==25.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: beautifulsoup4==4.13.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: certifi==2025.1.31 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2025.1.31)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (3.4.1)
# Collecting datasets==3.5.0 (from -r requirements.txt (line 9))
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting DateTime==5.5 (from -r requirements.txt (line 10))
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting dill==0.3.8 (from -r requirements.txt (line 11))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock==3.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (3.18.0)
# Requirement already satisfied: frozendict==2.4.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.4.6)
# Collecting frozenlist==1.6.0 (from -r requirements.txt (line 14))
#   Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting fsspec==2024.12.0 (from -r requirements.txt (line 15))
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub==0.30.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.30.2)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (3.10)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (3.1.6)
# Collecting jsonlines==4.0.0 (from -r requirements.txt (line 19))
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (3.0.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: multidict==6.4.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (6.4.3)
# Collecting multiprocess==0.70.16 (from -r requirements.txt (line 23))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: multitasking==0.0.11 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (0.0.11)
# Collecting networkx==3.2.1 (from -r requirements.txt (line 25))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 26))
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (24.2)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 28))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: peewee==3.17.9 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (3.17.9)
# Requirement already satisfied: platformdirs==4.3.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (4.3.7)
# Requirement already satisfied: propcache==0.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (0.3.1)
# Collecting pyarrow==19.0.1 (from -r requirements.txt (line 32))
#   Downloading pyarrow-19.0.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting python-dateutil==2.9.0.post0 (from -r requirements.txt (line 33))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (2025.2)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (6.0.2)
# Requirement already satisfied: regex==2024.11.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (2.32.3)
# Requirement already satisfied: safetensors==0.5.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (0.5.3)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (1.17.0)
# Requirement already satisfied: soupsieve==2.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (2.6)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 41))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tokenizers==0.21.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (0.21.1)
# Collecting torch==2.2.2 (from -r requirements.txt (line 43))
#   Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 44)) (4.67.1)
# Requirement already satisfied: transformers==4.51.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 45)) (4.51.3)
# Requirement already satisfied: typing_extensions==4.13.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (2025.2)
# Collecting urllib3==2.4.0 (from -r requirements.txt (line 48))
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting xxhash==3.5.0 (from -r requirements.txt (line 49))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl==1.20.0 (from -r requirements.txt (line 50))
#   Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: yfinance==0.2.55 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (0.2.55)
# Collecting zope.interface==7.2 (from -r requirements.txt (line 52))
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.2->-r requirements.txt (line 43))
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface==7.2->-r requirements.txt (line 52)) (75.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2->-r requirements.txt (line 43)) (12.5.82)
# Downloading aiohttp-3.11.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.9 MB/s eta 0:00:00
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 41.0 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 5.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.4 MB/s eta 0:00:00
# Downloading frozenlist-1.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 31.0 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 19.3 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 17.4 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 107.4 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 128.0 MB/s eta 0:00:00
# Downloading pyarrow-19.0.1-cp311-cp311-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 59.9 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 22.4 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 132.8 MB/s eta 0:00:00
# Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.6 MB/s eta 0:00:00
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 13.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.7 MB/s eta 0:00:00
# Downloading yarl-1.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.1/358.1 kB 35.3 MB/s eta 0:00:00
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 26.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 126.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 102.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 19.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 41.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 19.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 14.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: zope.interface, yarl, xxhash, urllib3, triton, sympy, python-dateutil, pyarrow, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, jsonlines, fsspec, frozenlist, dill, async-timeout, pandas, nvidia-cusolver-cu12, nvidia-cudnn-cu12, multiprocess, DateTime, torch, aiohttp, datasets
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.19.0
#     Uninstalling yarl-1.19.0:
#       Successfully uninstalled yarl-1.19.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.5.0
#     Uninstalling frozenlist-1.5.0:
#       Successfully uninstalled frozenlist-1.5.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed DateTime-5.5 aiohttp-3.11.16 async-timeout-5.0.1 datasets-3.5.0 dill-0.3.8 frozenlist-1.6.0 fsspec-2024.12.0 jsonlines-4.0.0 multiprocess-0.70.16 networkx-3.2.1 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 pandas-2.2.3 pyarrow-19.0.1 python-dateutil-2.9.0.post0 sympy-1.13.3 torch-2.2.2 triton-2.2.0 urllib3-2.4.0 xxhash-3.5.0 yarl-1.20.0 zope.interface-7.2
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.13.2)
# Collecting hf-xet>=0.1.4 (from huggingface_hub[hf_xet])
#   Downloading hf_xet-1.0.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines) (25.3.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2025.1.31)
# Downloading hf_xet-1.0.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 MB 46.6 MB/s eta 0:00:00
# Installing collected packages: hf-xet
# Successfully installed hf-xet-1.0.3

# %%
# !git checkout Aryan
# !git fetch
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !ls
# %cd nlp-earning-call
# !ls
# !git checkout Aryan
# !git fetch
# !git pull
# Out:
# nlp-earning-call  sample_data
# /content/nlp-earning-call
# archived  finbert_embeddings.py  model.py     requirements.txt	train.py
# data	  main.py		 __pycache__  stock_price.py
# Already on 'Aryan'
# Your branch is up to date with 'origin/Aryan'.
# Already up to date.

# %%
# !pip install --upgrade torch torchvision --index-url https://download.pytorch.org/whl/cu118
# Then upgrade transformers
# !pip install --upgrade transformers
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.6.0%2Bcu118-cp311-cp311-linux_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.12.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 96.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 61.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 118.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 9.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 38.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 19.7 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 4.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.21.5-py3-none-manylinux2014_x86_64.whl (147.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 16.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.0 MB/s eta 0:00:00
# Collecting triton==3.2.0 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.2.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 106.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu118/torch-2.6.0%2Bcu118-cp311-cp311-linux_x86_64.whl (848.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.7/848.7 MB 1.5 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.2.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (166.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.7/166.7 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: triton, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.21.5 nvidia-nvtx-cu11-11.8.86 sympy-1.13.1 torch-2.6.0+cu118 triton-3.2.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py", line 1967, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/timm_wrapper/configuration_timm_wrapper.py", line 25, in <module>
#     from timm.data import ImageNetInfo, infer_imagenet_subset
#   File "/usr/local/lib/python3.11/dist-packages/timm/__init__.py", line 2, in <module>
#     from .layers import (
#   File "/usr/local/lib/python3.11/dist-packages/timm/layers/__init__.py", line 8, in <module>
#     from .classifier import create_classifier, ClassifierHead, NormMlpClassifierHead, ClNormMlpClassifierHead
#   File "/usr/local/lib/python3.11/dist-packages/timm/layers/classifier.py", line 15, in <module>
#     from .create_norm import get_norm_layer
#   File "/usr/local/lib/python3.11/dist-packages/timm/layers/create_norm.py", line 14, in <module>
#     from torchvision.ops.misc import FrozenBatchNorm2d
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/__init__.py", line 9, in <module>
#     from .extension import _HAS_OPS  # usort:skip
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/extension.py", line 92, in <module>
#     _check_cuda_version()
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/extension.py", line 78, in _check_cuda_version
#     raise RuntimeError(
# RuntimeError: Detected that PyTorch and torchvision were compiled with different CUDA major versions. PyTorch has CUDA Version=11.8 and torchvision has CUDA Version=12.4. Please reinstall the torchvision that matches your PyTorch install.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/nlp-earning-call/train.py", line 91, in <module>
#     model = HierarchicalFinBERTModel()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/nlp-earning-call/model.py", line 10, in __init__
#     self.segment_encoder = AutoModel.from_pretrained(model_name)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 548, in from_pretrained
#     has_local_code = type(config) in cls._model_mapping.keys()
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 787, in keys
#     mapping_keys = [
#                    ^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 788, in <listcomp>
#     self._load_attr_from_module(key, name)
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 784, in _load_attr_from_module
#     return getattribute_from_module(self._modules[module_name], attr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 700, in getattribute_from_module
#     if hasattr(module, attr):
#        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py", line 1955, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py", line 1969, in _get_module
#     raise RuntimeError(
# RuntimeError: Failed to import transformers.models.timm_wrapper.configuration_timm_wrapper because of the following error (look up to see its traceback):
# Detected that PyTorch and torchvision were compiled with different CUDA major versions. PyTorch has CUDA Version=11.8 and torchvision has CUDA Version=12.4. Please reinstall the torchvision that matches your PyTorch install.

# %%
# !pip install -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiohttp==3.11.16 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (3.11.16)
# Requirement already satisfied: aiosignal==1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: async-timeout==5.0.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: attrs==25.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: beautifulsoup4==4.13.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: certifi==2025.1.31 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2025.1.31)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (3.4.1)
# Requirement already satisfied: datasets==3.5.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: DateTime==5.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.5)
# Requirement already satisfied: dill==0.3.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.3.8)
# Requirement already satisfied: filelock==3.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (3.18.0)
# Requirement already satisfied: frozendict==2.4.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.4.6)
# Requirement already satisfied: frozenlist==1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (1.6.0)
# Requirement already satisfied: fsspec==2024.12.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2024.12.0)
# Requirement already satisfied: huggingface-hub==0.30.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.30.2)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (3.10)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (3.1.6)
# Requirement already satisfied: jsonlines==4.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (3.0.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: multidict==6.4.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (6.4.3)
# Requirement already satisfied: multiprocess==0.70.16 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (0.70.16)
# Requirement already satisfied: multitasking==0.0.11 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (0.0.11)
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (3.2.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (1.26.4)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (2.2.3)
# Requirement already satisfied: peewee==3.17.9 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (3.17.9)
# Requirement already satisfied: platformdirs==4.3.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (4.3.7)
# Requirement already satisfied: propcache==0.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (0.3.1)
# Requirement already satisfied: pyarrow==19.0.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (19.0.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (2025.2)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (6.0.2)
# Requirement already satisfied: regex==2024.11.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 37)) (2.32.3)
# Requirement already satisfied: safetensors==0.5.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (0.5.3)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (1.17.0)
# Requirement already satisfied: soupsieve==2.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (2.6)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 41))
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting torch==2.2.2+cu118 (from -r requirements.txt (line 42))
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.2.2%2Bcu118-cp311-cp311-linux_x86_64.whl (819.2 MB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (4.67.1)
# Collecting transformers==4.32.1 (from -r requirements.txt (line 44))
#   Using cached transformers-4.32.1-py3-none-any.whl.metadata (118 kB)
# Requirement already satisfied: typing_extensions==4.13.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 45)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (2025.2)
# Requirement already satisfied: urllib3==2.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (2.4.0)
# Requirement already satisfied: xxhash==3.5.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 48)) (3.5.0)
# Requirement already satisfied: yarl==1.20.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 49)) (1.20.0)
# Requirement already satisfied: yfinance==0.2.55 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 50)) (0.2.55)
# Requirement already satisfied: zope.interface==7.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (7.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.8.87)
# Collecting nvidia-cudnn-cu11==8.7.0.84 (from torch==2.2.2+cu118->-r requirements.txt (line 42))
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-8.7.0.84-py3-none-manylinux1_x86_64.whl (728.5 MB)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.7.5.86)
# Collecting nvidia-nccl-cu11==2.19.3 (from torch==2.2.2+cu118->-r requirements.txt (line 42))
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.19.3-py3-none-manylinux1_x86_64.whl (135.3 MB)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2+cu118->-r requirements.txt (line 42)) (11.8.86)
# Collecting triton==2.2.0 (from torch==2.2.2+cu118->-r requirements.txt (line 42))
#   Using cached https://download.pytorch.org/whl/triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.32.1->-r requirements.txt (line 44))
#   Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface==7.2->-r requirements.txt (line 51)) (75.2.0)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 42.6 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 133.5 MB/s eta 0:00:00
# Installing collected packages: tokenizers, triton, sympy, nvidia-nccl-cu11, nvidia-cudnn-cu11, torch, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nccl-cu11
#     Found existing installation: nvidia-nccl-cu11 2.21.5
#     Uninstalling nvidia-nccl-cu11-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu11-2.21.5
#   Attempting uninstall: nvidia-cudnn-cu11
#     Found existing installation: nvidia-cudnn-cu11 9.1.0.70
#     Uninstalling nvidia-cudnn-cu11-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu11-9.1.0.70
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu118
#     Uninstalling torch-2.6.0+cu118:
#       Successfully uninstalled torch-2.6.0+cu118
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.2+cu118 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.32.1 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.2+cu118 which is incompatible.
# Successfully installed nvidia-cudnn-cu11-8.7.0.84 nvidia-nccl-cu11-2.19.3 sympy-1.13.3 tokenizers-0.13.3 torch-2.2.2+cu118 transformers-4.32.1 triton-2.2.0

# %%
# !python train.py
# Out:
# $WDR: possibly delisted; no timezone found
# delisted stock skipped
# $MYOV: possibly delisted; no timezone found
# delisted stock skipped
# $COUP: possibly delisted; no timezone found
# delisted stock skipped
# $BCOV: possibly delisted; no timezone found
# delisted stock skipped
# $AIMC: possibly delisted; no timezone found
# delisted stock skipped
# $SGEN: possibly delisted; no timezone found
# delisted stock skipped
# $AAWW: possibly delisted; no timezone found
# delisted stock skipped
# $SIVB: possibly delisted; no timezone found
# delisted stock skipped
# $CTIC: possibly delisted; no timezone found
# delisted stock skipped
# $XLNX: possibly delisted; no timezone found
# delisted stock skipped
# $AYX: possibly delisted; no timezone found
# delisted stock skipped
# $STNG): possibly delisted; no timezone found
# delisted stock skipped
# $WWE: possibly delisted; no timezone found
# delisted stock skipped
# $CHS: possibly delisted; no timezone found
# delisted stock skipped
# $ATC): possibly delisted; no timezone found
# delisted stock skipped
# $CTK: possibly delisted; no timezone found
# delisted stock skipped
# $ZUO: possibly delisted; no timezone found
# delisted stock skipped
# $LHCG: possibly delisted; no timezone found
# delisted stock skipped
# $BCOR: possibly delisted; no timezone found
# delisted stock skipped
# $SIX: possibly delisted; no timezone found
# delisted stock skipped
# $ICPT: possibly delisted; no timezone found
# delisted stock skipped
# $VLDR: possibly delisted; no timezone found
# delisted stock skipped
# $HMLP: possibly delisted; no timezone found
# delisted stock skipped
# $ITCB: possibly delisted; no timezone found
# delisted stock skipped
# $GMLP: possibly delisted; no timezone found
# delisted stock skipped
# $TIG: possibly delisted; no timezone found
# delisted stock skipped
# $NCR: possibly delisted; no timezone found
# delisted stock skipped
# $SBNY: possibly delisted; no price data found  (1d 2021-07-17 -> 2021-07-21) (Yahoo error = "Data doesn't exist for startDate = 1626494400, endDate = 1626840000")
# delisted stock skipped
# $SBNY: possibly delisted; no price data found  (1d 2021-10-16 -> 2021-10-20) (Yahoo error = "Data doesn't exist for startDate = 1634356800, endDate = 1634702400")
# delisted stock skipped
# $SQ: possibly delisted; no timezone found
# delisted stock skipped
# $CPE: possibly delisted; no timezone found
# delisted stock skipped
# $CDMO: possibly delisted; no timezone found
# delisted stock skipped
# $TCS: possibly delisted; no timezone found
# delisted stock skipped
# $EBIX: possibly delisted; no timezone found
# delisted stock skipped
# $ATVI: possibly delisted; no timezone found
# delisted stock skipped
# $TFFP: possibly delisted; no timezone found
# delisted stock skipped
# $AAWW: possibly delisted; no timezone found
# delisted stock skipped
# $APTX: possibly delisted; no timezone found
# delisted stock skipped
# $DISC.A: possibly delisted; no timezone found
# delisted stock skipped
# $COUP: possibly delisted; no timezone found
# delisted stock skipped
# $CCXI: possibly delisted; no timezone found
# delisted stock skipped
# $ATTO: possibly delisted; no timezone found
# delisted stock skipped
# $LHDX: possibly delisted; no timezone found
# delisted stock skipped
# $PRFT: possibly delisted; no timezone found
# delisted stock skipped
# $RETA: possibly delisted; no timezone found
# delisted stock skipped
# $RDS.A: possibly delisted; no timezone found
# delisted stock skipped
# $VRS: possibly delisted; no timezone found
# delisted stock skipped
# $UFS: possibly delisted; no timezone found
# delisted stock skipped
# $DISC.A: possibly delisted; no timezone found
# delisted stock skipped
# $IEA: possibly delisted; no timezone found
# delisted stock skipped
# $RAIN: possibly delisted; no price data found  (1d 2022-08-04 -> 2022-08-07) (Yahoo error = "Data doesn't exist for startDate = 1659585600, endDate = 1659844800")
# delisted stock skipped
# $TPX: possibly delisted; no timezone found
# delisted stock skipped
# $NCR: possibly delisted; no timezone found
# delisted stock skipped
# $FCAU: possibly delisted; no timezone found
# delisted stock skipped
# $IDSY: possibly delisted; no timezone found
# delisted stock skipped
# $COUP: possibly delisted; no timezone found
# delisted stock skipped
# $TWOU: possibly delisted; no timezone found
# delisted stock skipped
# $SIVB: possibly delisted; no timezone found
# delisted stock skipped
# $EBIX: possibly delisted; no timezone found
# delisted stock skipped
# $XLNX: possibly delisted; no timezone found
# delisted stock skipped
# $CDMO: possibly delisted; no timezone found
# delisted stock skipped
# $RTN: possibly delisted; no timezone found
# delisted stock skipped
# $WKME: possibly delisted; no timezone found
# delisted stock skipped
# $BKCC: possibly delisted; no timezone found
# delisted stock skipped
# $SBNY: possibly delisted; no price data found  (1d 2021-04-18 -> 2021-04-22) (Yahoo error = "Data doesn't exist for startDate = 1618718400, endDate = 1619064000")
# delisted stock skipped
# $SFT: possibly delisted; no price data found  (1d 2021-03-08 -> 2021-03-11)
# delisted stock skipped
# $BKI: possibly delisted; no timezone found
# delisted stock skipped
# $REGI: possibly delisted; no timezone found
# delisted stock skipped
# $HZNP: possibly delisted; no timezone found
# delisted stock skipped
# $SIX: possibly delisted; no timezone found
# delisted stock skipped
# $CPSI: possibly delisted; no timezone found
# delisted stock skipped
# $LPI: possibly delisted; no timezone found
# delisted stock skipped
# $HA: possibly delisted; no timezone found
# delisted stock skipped
# $WWE: possibly delisted; no timezone found
# delisted stock skipped
# $VVNT: possibly delisted; no timezone found
# delisted stock skipped
# $GPS: possibly delisted; no timezone found
# delisted stock skipped
# $AFYA): possibly delisted; no timezone found
# delisted stock skipped
# $STON: possibly delisted; no timezone found
# delisted stock skipped
# $ABTX: possibly delisted; no timezone found
# delisted stock skipped
# $BIG: possibly delisted; no timezone found
# delisted stock skipped
# $AINV: possibly delisted; no timezone found
# delisted stock skipped
# $PGTI: possibly delisted; no timezone found
# delisted stock skipped
# $VVI: possibly delisted; no timezone found
# delisted stock skipped
# $BCOV: possibly delisted; no timezone found
# delisted stock skipped
# $ATVI: possibly delisted; no timezone found
# delisted stock skipped
# $HMSY: possibly delisted; no timezone found
# delisted stock skipped
# $CAMP: possibly delisted; no price data found  (1d 2019-09-23 -> 2019-09-27) (Yahoo error = "Data doesn't exist for startDate = 1569211200, endDate = 1569556800")
# delisted stock skipped
# $SQ: possibly delisted; no timezone found
# delisted stock skipped
# $MIME: possibly delisted; no timezone found
# delisted stock skipped
# $DISC.A: possibly delisted; no timezone found
# delisted stock skipped
# $NTCO: possibly delisted; no timezone found
# delisted stock skipped
# $FTCH: possibly delisted; no timezone found
# delisted stock skipped
# $CIR: possibly delisted; no timezone found
# delisted stock skipped
# $BGCP: possibly delisted; no timezone found
# delisted stock skipped
# $NEWR: possibly delisted; no timezone found
# delisted stock skipped
# $RETA: possibly delisted; no timezone found
# delisted stock skipped
# $KSU: possibly delisted; no timezone found
# delisted stock skipped
# $TDCX: possibly delisted; no timezone found
# delisted stock skipped
# $TWNK: possibly delisted; no timezone found
# delisted stock skipped
# $BSIG: possibly delisted; no timezone found
# delisted stock skipped
# $TPRE: possibly delisted; no timezone found
# delisted stock skipped
# $ARCE: possibly delisted; no timezone found
# delisted stock skipped
# $MFGP: possibly delisted; no timezone found
# delisted stock skipped
# $MNTV: possibly delisted; no timezone found
# delisted stock skipped
# $PGTI: possibly delisted; no timezone found
# delisted stock skipped
# $VRAY: possibly delisted; no timezone found
# delisted stock skipped
# $SJI: possibly delisted; no timezone found
# delisted stock skipped
# $VNE: possibly delisted; no timezone found
# delisted stock skipped
# $CDMO: possibly delisted; no timezone found
# delisted stock skipped
# $CMRE): possibly delisted; no timezone found
# delisted stock skipped
# $OCSI: possibly delisted; no timezone found
# delisted stock skipped
# $GPL: possibly delisted; no timezone found
# delisted stock skipped
# $GCP: possibly delisted; no timezone found
# delisted stock skipped
# $HEAR: possibly delisted; no timezone found
# delisted stock skipped
# $NLS: possibly delisted; no timezone found
# delisted stock skipped
# $WETF: possibly delisted; no timezone found
# delisted stock skipped
# $ESTA): possibly delisted; no timezone found
# delisted stock skipped
# $SMTS: possibly delisted; no timezone found
# delisted stock skipped
# $NLS: possibly delisted; no timezone found
# delisted stock skipped
# $BKI: possibly delisted; no timezone found
# delisted stock skipped
# $VSTO: possibly delisted; no timezone found
# delisted stock skipped
# $GHL: possibly delisted; no timezone found
# delisted stock skipped
# $DRNA: possibly delisted; no timezone found
# delisted stock skipped
# $RAD: possibly delisted; no timezone found
# delisted stock skipped
# $ICPT: possibly delisted; no timezone found
# delisted stock skipped
# $BKCC: possibly delisted; no timezone found
# delisted stock skipped
# $FLXN: possibly delisted; no timezone found
# delisted stock skipped
# $MYOK: possibly delisted; no timezone found
# delisted stock skipped
# $MIME: possibly delisted; no timezone found
# delisted stock skipped
# $EBIX: possibly delisted; no timezone found
# delisted stock skipped
# $CEIX: possibly delisted; no timezone found
# delisted stock skipped
# $CNSL: possibly delisted; no timezone found
# delisted stock skipped
# $FLXN: possibly delisted; no timezone found
# delisted stock skipped
# $DSKE: possibly delisted; no timezone found
# delisted stock skipped
# $CTK: possibly delisted; no timezone found
# delisted stock skipped
# $CVET: possibly delisted; no timezone found
# delisted stock skipped
# $EPZM: possibly delisted; no timezone found
# delisted stock skipped
# $XM: possibly delisted; no timezone found
# delisted stock skipped
# $UROV: possibly delisted; no timezone found
# delisted stock skipped
# $CDK: possibly delisted; no timezone found
# delisted stock skipped
# $TFFP: possibly delisted; no timezone found
# delisted stock skipped
# $TWTR: possibly delisted; no timezone found
# delisted stock skipped
# $SOVO: possibly delisted; no timezone found
# delisted stock skipped
# True label distribution (mapped to -1/0/+1): {1: 267, 0: 325, -1: 264}
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# Epoch 1/5:   0% 0/684 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (8322 > 512). Running this sequence through the model will result in indexing errors
# Epoch 1/5: 100% 684/684 [09:41<00:00,  1.18it/s]
# Epoch 1 Train Loss: 1.1044
# Epoch 1 Validation Accuracy: 0.4070
#
# Epoch 2/5:   2% 16/684 [00:13<10:36,  1.05it/s]
